# %% [markdown]
# ## Commonly Asked Python Live Coding Questions
#
# ### 1. String Manipulation
# - **Reverse a String**: Write a function that takes a string and returns the reversed version.
# - **Palindrome Check**: Write a function that checks if a given string is a palindrome.
# - **Anagram Check**: Determine if two strings are anagrams of each other.
# - **Longest Substring Without Repeating Characters**: Given a string, find the length of the longest substring without repeating characters.
#
# ### 2. Array/Lists
# - **Two Sum**: Given an array of integers, return the indices of the two numbers that add up to a specific target.
# - **Maximum Subarray (Kadane's Algorithm)**: Find the contiguous subarray (containing at least one number) which has the largest sum.
# - **Move Zeroes**: Write a function that moves all zeroes in an array to the end, maintaining the order of the other elements.
# - **Merge Sorted Arrays**: Merge two sorted arrays into one sorted array.
# - **Product of Array Except Self**: Given an array, return an array where each element at index `i` is the product of all the numbers in the original array except the one at `i`.
#
# ### 3. Recursion
# - **Fibonacci Sequence**: Implement a recursive function to return the `n`th Fibonacci number.
# - **Factorial Calculation**: Write a recursive function to calculate the factorial of a number.
# - **Permutations**: Generate all permutations of a list of numbers.
# - **Tower of Hanoi**: Solve the Tower of Hanoi problem recursively.
#
# ### 4. Sorting and Searching
# - **Binary Search**: Implement binary search on a sorted array.
# - **Merge Sort**: Implement the merge sort algorithm.
# - **Quick Sort**: Implement the quick sort algorithm.
# - **Find First and Last Position in Sorted Array**: Given a sorted array, find the first and last position of a given target.
#
# ### 5. Linked Lists
# - **Reverse a Linked List**: Write a function to reverse a singly linked list.
# - **Detect a Cycle in a Linked List**: Determine if a linked list has a cycle (Floyd’s Cycle-Finding Algorithm).
# - **Merge Two Sorted Linked Lists**: Merge two sorted linked lists into a single sorted linked list.
# - **Find the Intersection of Two Linked Lists**: Given two singly linked lists, determine if they intersect and return the intersection node.
#
# ### 6. Trees
# - **Binary Tree Inorder Traversal**: Implement in-order traversal of a binary tree.
# - **Maximum Depth of Binary Tree**: Find the maximum depth of a binary tree.
# - **Validate Binary Search Tree**: Check if a binary tree is a valid binary search tree (BST).
# - **Lowest Common Ancestor in BST**: Given a binary search tree, find the lowest common ancestor (LCA) of two given nodes.
#
# ### 7. Dynamic Programming
# - **Climbing Stairs**: You are climbing a staircase. It takes `n` steps to reach the top. Each time you can either climb 1 or 2 steps. Write a function that computes the number of distinct ways to reach the top.
# - **Coin Change Problem**: Given a set of coin denominations and a total amount, find the minimum number of coins needed to make that amount.
# - **Longest Increasing Subsequence**: Find the length of the longest increasing subsequence in a given array.
# - **Edit Distance**: Given two strings, find the minimum number of operations required to convert one string into the other.
#
# ### 8. Graphs
# - **Depth-First Search (DFS) & Breadth-First Search (BFS)**: Implement DFS and BFS for graph traversal.
# - **Detect Cycle in Directed Graph**: Given a directed graph, detect if there's a cycle in it.
# - **Shortest Path in a Grid (BFS)**: Given a grid, find the shortest path from top-left to bottom-right.
# - **Connected Components in a Graph**: Given an undirected graph, find all connected components.
#
# ### 9. Other Topics
# - **Least Recently Used (LRU) Cache**: Implement an LRU cache.
# - **Design a Stack with `getMin()` Operation**: Implement a stack that supports push, pop, and retrieving the minimum element in constant time.
# - **Valid Parentheses**: Write a function to check if a string containing only parentheses is valid.
# - **Implement a Queue using Stacks**: Simulate the behavior of a queue using two stacks.

# %%
##Reverse a String: Write a function that takes a string and returns the reversed version.
def rev_str(s:str)->str:
    return s[::-1]

# %%
rev_str('sivahari')
# Out:
# 'irahavis'

# %%
a = 'sivahari'
a[::-2]
# Out:
# 'iaai'

# %%
#Palindrome Check: Write a function that checks if a given string is a palindrome.
def is_palindrome(s:str)->bool:
    return s[::-1] == s

# %%
is_palindrome('amaa')
# Out:
# False

# %% [markdown]
# **Longest Substring Without Repeating Characters**: Given a string, find the length of the longest substring without repeating characters.
#
# Examples:
#
#     Input: “ABCBC”
#     Output: 3
#     Explanation: The longest substring without repeating characters is “ABC”
#
#     Input: “AAA”
#     Output: 1
#     Explanation: The longest substring without repeating characters is “A”
#
#     Input: “GEEKSFORGEEKS”
#     Output: 7
#     Explanation: The longest substrings without repeating characters are “EKSFORG” and “KSFORGE”, with lengths of 7.

# %%
def log_sustring(s:str)->int:
    left = 0
    right = 0
    n = len(s)
    max_len = 0
    cnt = 0
    while right < n:
        if s[right] in s[left:right]:
            max_len = max(max_len, right - left)
            while(s[left] != s[right]):
                left += 1
                cnt += 1
            left += 1
        right += 1
    max_len = max(max_len, right - left)
    print(cnt)
    return max_len

# %%
log_sustring("GEEKSFORGEEKS")
# Out:
# 7
# 7

# %%
log_sustring("CefAjklABAB")
# Out:
# 6
# 7

# %%
log_sustring("ABCBC")
# Out:
# 1
# 3

# %%
def log_sustring_dict(s:str)->int:
    left = 0
    right = 0
    n = len(s)
    max_len = 0
    alpos = {}
    while right < n:
        if s[right] in alpos:
            if alpos[s[right]] > left:
                max_len = max(max_len, right - left)
                left = alpos[s[right]] + 1
        alpos[s[right]] = right
        right += 1

    return max_len

# %%
log_sustring_dict("ABCBC")
# Out:
# 3

# %%
log_sustring_dict("CefAjklABAB")
# Out:
# 7

# %% [markdown]
# **Factorial Calculation**: Write a recursive function to calculate the factorial of a number.
# Examples:
#
#     Input: 5
#     Output: 120
#     Explanation: 5! = 5 * 4 * 3 * 2 * 1 = 120
#
#     Input: 4
#     Output: 24
#     Explanation: 4! = 4 * 3 * 2 * 1 = 24

# %%
def factorial(n:int)->int:
    if n == 1:
        return n
    return n*factorial(n-1)
#O(n) time and O(n) space (stack for recusrsion)

# %%
factorial(5)
# Out:
# 120

# %%
def factorial_less_space(n:int)->int:
    factorial = 1
    for i in range(1,n+1):
        factorial *= i
    return factorial
#O(n) time and O(1)

# %%
factorial_less_space(5)
# Out:
# 120

# %% [markdown]
# ### Program for Tower of Hanoi Algorithm
#
# Tower of Hanoi is a mathematical puzzle where we have three rods (A, B, and C) and N disks. Initially, all the disks are stacked in decreasing value of diameter i.e., the smallest disk is placed on the top and they are on rod A. The objective of the puzzle is to move the entire stack to another rod (here considered C), obeying the following simple rules:
#
#     Only one disk can be moved at a time.
#     Each move consists of taking the upper disk from one of the stacks and placing it on top of another stack i.e. a disk can only be moved if it is the uppermost disk on a stack.
#     No disk may be placed on top of a smaller disk.
#
# Examples:
#
#     Input: 2
#     Output: Disk 1 moved from A to B
#     Disk 2 moved from A to C
#     Disk 1 moved from B to C
#
#     Input: 3
#     Output: Disk 1 moved from A to C
#     Disk 2 moved from A to B
#     Disk 1 moved from C to B
#     Disk 3 moved from A to C
#     Disk 1 moved from B to A
#     Disk 2 moved from B to C
#     Disk 1 moved from A to C

# %%
def hanoi_tower(tower_a,tower_b,tower_c,n):
    if n==0:
        return
    hanoi_tower(tower_a,tower_c,tower_b,n-1)
    print(f"take disk{n} from {tower_a} to {tower_c}")
    hanoi_tower(tower_b,tower_a,tower_c,n-1)

# %%
hanoi_tower('A','B','C',2)
# Out:
# take disk1 from A to B
# take disk2 from A to C
# take disk1 from B to C

# %%
hanoi_tower('A','B','C',3)
# Out:
# take disk1 from A to C
# take disk2 from A to B
# take disk1 from C to B
# take disk3 from A to C
# take disk1 from B to A
# take disk2 from B to C
# take disk1 from A to C

# %%
hanoi_tower('A','B','C',5)
# Out:
# take disk1 from A to C
# take disk2 from A to B
# take disk1 from C to B
# take disk3 from A to C
# take disk1 from B to A
# take disk2 from B to C
# take disk1 from A to C
# take disk4 from A to B
# take disk1 from C to B
# take disk2 from C to A
# take disk1 from B to A
# take disk3 from C to B
# take disk1 from A to C
# take disk2 from A to B
# take disk1 from C to B
# take disk5 from A to C
# take disk1 from B to A
# take disk2 from B to C
# take disk1 from A to C
# take disk3 from B to A
# take disk1 from C to B
# take disk2 from C to A
# take disk1 from B to A
# take disk4 from B to C
# take disk1 from A to C
# take disk2 from A to B
# take disk1 from C to B
# take disk3 from A to C
# take disk1 from B to A
# take disk2 from B to C
# take disk1 from A to C
