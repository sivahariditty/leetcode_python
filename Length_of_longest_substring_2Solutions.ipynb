# %% [markdown]
# Example 1:
#
# Input: s = "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3.
#
# Example 2:
#
# Input: s = "bbbbb"
# Output: 1
# Explanation: The answer is "b", with the length of 1.
#
# Example 3:
#
# Input: s = "pwwkew"
# Output: 3
# Explanation: The answer is "wke", with the length of 3.
# Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.

# %%
def lengthOfLongestSubstring(s: str) -> int:
    if len(s) == 0:
        return 0
    start = 0
    end = 0
    mxcnt = 0
    substr = s[0]
    while end < len(s):
        if s[end] not in s[start:end]:
            end += 1
        else :
            while(s[start] != s[end]):
                start += 1
            start += 1
            end += 1
        if mxcnt < (end - start):
            mxcnt = end - start
    return mxcnt

# %%
def lengthOfLongestSubstring(self, s: str) -> int:
    indx = {}
    start = 0
    end = 0
    mxcnt = 0
    while end < len(s):
        if s[end] in indx and indx[s[end]] >= start:
            start = indx[s[end]] + 1
        indx[s[end]] = end
        end = end + 1
        mxcnt = max(mxcnt, (end-start))
    return mxcnt
